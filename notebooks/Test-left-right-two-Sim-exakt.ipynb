# %%
from _bootstrap import setup_project_path
setup_project_path()
from run.binom_test_interactive_show import show_binom_test

n = 100
p0 = 0.6
alpha = 0.05
runs = 10000
seed = 42
side = "left"   # "left" oder "two"

region, a_hat = show_binom_test(n=n, p0=p0, alpha=alpha, runs=runs, seed=seed, side=side, nsigma=5.0)
print("Region:", region)
print("alpha_hat:", round(a_hat, 4))
# Out:
# Region: BinomCriticalRegion(k_left=51, k_right=None)
# alpha_hat: 0.041
